# %% [markdown]
# Training v25
# --
# ------------------------------------------------------
# 32x32 - HOG - 75.000 Images
#
# NN - Input > Hidden 56 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 32
COLOR_TYPE = 'hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 56

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 2s 6ms/step - loss: 1.2132 - accuracy: 0.6718 - val_loss: 0.2862 - val_accuracy: 0.9549
# Epoch 2/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.9595 - val_loss: 0.1605 - val_accuracy: 0.9701
# Epoch 3/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1454 - accuracy: 0.9753 - val_loss: 0.1210 - val_accuracy: 0.9775
# Epoch 4/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 0.9789 - val_loss: 0.0992 - val_accuracy: 0.9799
# Epoch 5/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9823 - val_loss: 0.0871 - val_accuracy: 0.9819
# Epoch 6/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9849 - val_loss: 0.0812 - val_accuracy: 0.9821
# Epoch 7/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9872 - val_loss: 0.0723 - val_accuracy: 0.9833
# Epoch 8/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9868 - val_loss: 0.0641 - val_accuracy: 0.9860
# Epoch 9/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9884 - val_loss: 0.0648 - val_accuracy: 0.9849
# Epoch 10/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9900 - val_loss: 0.0571 - val_accuracy: 0.9869
# Epoch 11/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9911 - val_loss: 0.0560 - val_accuracy: 0.9880
# Epoch 12/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9909 - val_loss: 0.0637 - val_accuracy: 0.9842
# Epoch 13/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9916 - val_loss: 0.0544 - val_accuracy: 0.9875
# Epoch 14/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9936 - val_loss: 0.0502 - val_accuracy: 0.9895
# Epoch 15/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9936 - val_loss: 0.0537 - val_accuracy: 0.9875
# Epoch 16/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9930 - val_loss: 0.0496 - val_accuracy: 0.9893
# Epoch 17/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9941 - val_loss: 0.0486 - val_accuracy: 0.9899
# Epoch 18/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9944 - val_loss: 0.0510 - val_accuracy: 0.9880
# Epoch 19/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9944 - val_loss: 0.0485 - val_accuracy: 0.9893
# Epoch 20/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9950 - val_loss: 0.0498 - val_accuracy: 0.9894
# Epoch 21/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9953 - val_loss: 0.0459 - val_accuracy: 0.9903
# Epoch 22/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0239 - accuracy: 0.9955 - val_loss: 0.0469 - val_accuracy: 0.9897
# Epoch 23/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9956 - val_loss: 0.0491 - val_accuracy: 0.9886
# Epoch 24/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9950 - val_loss: 0.0470 - val_accuracy: 0.9900
# Epoch 25/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9961 - val_loss: 0.0573 - val_accuracy: 0.9860
# Epoch 26/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9952 - val_loss: 0.0465 - val_accuracy: 0.9896
# Epoch 27/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9958 - val_loss: 0.0443 - val_accuracy: 0.9906
# Epoch 28/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9958 - val_loss: 0.0446 - val_accuracy: 0.9909
# Epoch 29/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9959 - val_loss: 0.0437 - val_accuracy: 0.9902
# Epoch 30/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9967 - val_loss: 0.0429 - val_accuracy: 0.9913
# Epoch 31/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9970 - val_loss: 0.0529 - val_accuracy: 0.9877
# Epoch 32/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9962 - val_loss: 0.0461 - val_accuracy: 0.9901
# Epoch 33/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9968 - val_loss: 0.0488 - val_accuracy: 0.9899
# Epoch 34/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9970 - val_loss: 0.0454 - val_accuracy: 0.9907
# Epoch 35/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9970 - val_loss: 0.0446 - val_accuracy: 0.9906
# Epoch 36/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9977 - val_loss: 0.0457 - val_accuracy: 0.9908
# Epoch 37/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.0458 - val_accuracy: 0.9907
# Epoch 38/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9970 - val_loss: 0.0562 - val_accuracy: 0.9875
# Epoch 39/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9965 - val_loss: 0.0454 - val_accuracy: 0.9902
# Epoch 40/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.0479 - val_accuracy: 0.9906
# Epoch 41/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9973 - val_loss: 0.0455 - val_accuracy: 0.9903
# Epoch 42/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9978 - val_loss: 0.0448 - val_accuracy: 0.9912
# Epoch 43/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9979 - val_loss: 0.0451 - val_accuracy: 0.9908
# Epoch 44/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 0.0476 - val_accuracy: 0.9904
# Epoch 45/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.0448 - val_accuracy: 0.9912
# Epoch 46/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0462 - val_accuracy: 0.9902
# Epoch 47/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9978 - val_loss: 0.0467 - val_accuracy: 0.9901
# Epoch 48/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0447 - val_accuracy: 0.9920
# Epoch 49/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.0452 - val_accuracy: 0.9915
# Epoch 50/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 0.0484 - val_accuracy: 0.9904
# Time for training:     21.363

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 0s 668us/step - loss: 0.0497 - accuracy: 0.9900
# Test results - Loss: 0.04973656311631203 - Accuracy: 0.9900000095367432%
# Time for testing:      0.432
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-01-23-36-59_mlp_X_56_10_Y_32x32_hog_75000_loss_0.0497_acc_0.9900

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
