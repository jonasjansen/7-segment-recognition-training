# %% [markdown]
# Training v26
# --
# ------------------------------------------------------
# 128x128 - HOG - 75.000 Images
#
# NN - Input > Hidden 56 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 128
COLOR_TYPE = 'hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 56

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
#  - ETA: 3s - loss: 1.3884 - accuracy: 0.6070
# Epoch 2/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0521 - accuracy: 0.9953 - val_loss: 0.0361 - val_accuracy: 0.9957
# Epoch 3/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0281 - accuracy: 0.9975 - val_loss: 0.0292 - val_accuracy: 0.9953
# Epoch 4/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0186 - accuracy: 0.9979 - val_loss: 0.0250 - val_accuracy: 0.9958
# Epoch 5/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0123 - accuracy: 0.9987 - val_loss: 0.0221 - val_accuracy: 0.9966
# Epoch 6/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0088 - accuracy: 0.9990 - val_loss: 0.0210 - val_accuracy: 0.9966
# Epoch 7/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.0207 - val_accuracy: 0.9963
# Epoch 8/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0052 - accuracy: 0.9995 - val_loss: 0.0209 - val_accuracy: 0.9964
# Epoch 9/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0040 - accuracy: 0.9996 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 10/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0208 - val_accuracy: 0.9962
# Epoch 11/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0206 - val_accuracy: 0.9967
# Epoch 12/50
# 192/192 [==============================] - 5s 26ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9968
# Epoch 13/50
#  - ETA: 3s - loss: 0.0023 - accuracy: 0.9998
# Epoch 14/50
# 192/192 [==============================] - 5s 27ms/step - loss: 9.7936e-04 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9968
# Epoch 15/50
# 192/192 [==============================] - 5s 27ms/step - loss: 7.9311e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9967
# Epoch 16/50
# 192/192 [==============================] - 5s 27ms/step - loss: 6.9264e-04 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9964
# Epoch 17/50
# 192/192 [==============================] - 5s 27ms/step - loss: 5.9912e-04 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9966
# Epoch 18/50
# 192/192 [==============================] - 5s 27ms/step - loss: 5.0638e-04 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 0.9967
# Epoch 19/50
# 192/192 [==============================] - 5s 27ms/step - loss: 4.4024e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9967
# Epoch 20/50
# 192/192 [==============================] - 5s 27ms/step - loss: 3.6421e-04 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 0.9970
# Epoch 21/50
#  - ETA: 0s - loss: 3.3973e-04 - accuracy: 1.0000
# Epoch 22/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.8120e-04 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9969
# Epoch 23/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.4331e-04 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9967
# Epoch 24/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.3310e-04 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 0.9967
# Epoch 25/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.9233e-04 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9968
# Epoch 26/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.7231e-04 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 0.9968
# Epoch 27/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.4812e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9969
# Epoch 28/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.3265e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 0.9967
# Epoch 29/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.2126e-04 - accuracy: 1.0000 - val_loss: 0.0231 - val_accuracy: 0.9969
# Epoch 30/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.0861e-04 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 0.9967
# Epoch 31/50
#  - ETA: 3s - loss: 9.4457e-05 - accuracy: 1.0000
# Epoch 32/50
#  - ETA: 2s - loss: 8.4568e-05 - accuracy: 1.0000
# Epoch 33/50
# 192/192 [==============================] - 5s 27ms/step - loss: 7.7794e-05 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9970
# Epoch 34/50
# 192/192 [==============================] - 5s 27ms/step - loss: 6.5784e-05 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9971
# Epoch 35/50
# 192/192 [==============================] - 5s 27ms/step - loss: 5.7463e-05 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9969
# Epoch 36/50
# 192/192 [==============================] - 5s 27ms/step - loss: 5.4025e-05 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9968
# Epoch 37/50
# 192/192 [==============================] - 5s 27ms/step - loss: 4.6673e-05 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9969
# Epoch 38/50
# 192/192 [==============================] - 5s 27ms/step - loss: 4.3827e-05 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9967
# Epoch 39/50
# 192/192 [==============================] - 5s 27ms/step - loss: 3.8169e-05 - accuracy: 1.0000 - val_loss: 0.0255 - val_accuracy: 0.9967
# Epoch 40/50
# 192/192 [==============================] - 5s 28ms/step - loss: 3.3555e-05 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9970
# Epoch 41/50
# 192/192 [==============================] - 5s 28ms/step - loss: 3.0580e-05 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9968
# Epoch 42/50
# 192/192 [==============================] - 5s 28ms/step - loss: 3.0351e-05 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9970
# Epoch 43/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.5230e-05 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9969
# Epoch 44/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.1521e-05 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9968
# Epoch 45/50
# 192/192 [==============================] - 5s 27ms/step - loss: 2.0240e-05 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9970
# Epoch 46/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.8033e-05 - accuracy: 1.0000 - val_loss: 0.0269 - val_accuracy: 0.9968
# Epoch 47/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.6538e-05 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9969
# Epoch 48/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.4793e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9970
# Epoch 49/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.3479e-05 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9969
# Epoch 50/50
# 192/192 [==============================] - 5s 27ms/step - loss: 1.1703e-05 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9969
# Time for training:    259.512

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0303 - accuracy: 0.9963
# Test results - Loss: 0.030257156118750572 - Accuracy: 0.9963333606719971%
# Time for testing:      1.218
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-01-23-44-44_mlp_X_56_10_Y_128x128_hog_75000_loss_0.0303_acc_0.9963

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
