# %% [markdown]
# Training v20
# --
# ------------------------------------------------------
# 32x32 - Gray - 75.000 Images
#
# NN - Input > Hidden 56 > Output
#
# 10 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 32
COLOR_TYPE = 'gray'
BATCH_SIZE = 75000
EPOCHS = 10
HIDDEN_LAYER = 56

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/10
# 192/192 [==============================] - 1s 6ms/step - loss: 1.5014 - accuracy: 0.5582 - val_loss: 0.5194 - val_accuracy: 0.9031
# Epoch 2/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4545 - accuracy: 0.9103 - val_loss: 0.2975 - val_accuracy: 0.9373
# Epoch 3/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2824 - accuracy: 0.9431 - val_loss: 0.2057 - val_accuracy: 0.9607
# Epoch 4/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2065 - accuracy: 0.9602 - val_loss: 0.1644 - val_accuracy: 0.9663
# Epoch 5/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1674 - accuracy: 0.9669 - val_loss: 0.1496 - val_accuracy: 0.9682
# Epoch 6/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1417 - accuracy: 0.9710 - val_loss: 0.1179 - val_accuracy: 0.9747
# Epoch 7/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 0.9759 - val_loss: 0.1033 - val_accuracy: 0.9776
# Epoch 8/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9768 - val_loss: 0.0963 - val_accuracy: 0.9770
# Epoch 9/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0942 - accuracy: 0.9813 - val_loss: 0.0833 - val_accuracy: 0.9827
# Epoch 10/10
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9801 - val_loss: 0.0854 - val_accuracy: 0.9792
# Time for training:      5.142

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 0s 726us/step - loss: 0.0944 - accuracy: 0.9791
# Test results - Loss: 0.09443491697311401 - Accuracy: 0.9791333079338074%
# Time for testing:      0.446
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-01-23-06-53_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0944_acc_0.9791

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
