# %% [markdown]
# Training v27
# --
# ------------------------------------------------------
# 32x32 - Sauvola - 75.000 Images
#
# NN - Input > Hidden 56 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 32
COLOR_TYPE = 'sauvola'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 56

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 2s 8ms/step - loss: 1.8943 - accuracy: 0.4396 - val_loss: 1.0400 - val_accuracy: 0.8096
# Epoch 2/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.9446 - accuracy: 0.8199 - val_loss: 0.6693 - val_accuracy: 0.8811
# Epoch 3/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.6271 - accuracy: 0.8873 - val_loss: 0.4932 - val_accuracy: 0.9183
# Epoch 4/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.9118 - val_loss: 0.4117 - val_accuracy: 0.9251
# Epoch 5/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.4035 - accuracy: 0.9258 - val_loss: 0.3459 - val_accuracy: 0.9299
# Epoch 6/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.9325 - val_loss: 0.2945 - val_accuracy: 0.9439
# Epoch 7/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2984 - accuracy: 0.9432 - val_loss: 0.2636 - val_accuracy: 0.9474
# Epoch 8/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.9468 - val_loss: 0.2391 - val_accuracy: 0.9561
# Epoch 9/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2471 - accuracy: 0.9532 - val_loss: 0.2288 - val_accuracy: 0.9539
# Epoch 10/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9559 - val_loss: 0.2209 - val_accuracy: 0.9425
# Epoch 11/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.2103 - accuracy: 0.9565 - val_loss: 0.1934 - val_accuracy: 0.9571
# Epoch 12/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.9614 - val_loss: 0.1769 - val_accuracy: 0.9597
# Epoch 13/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1843 - accuracy: 0.9617 - val_loss: 0.1617 - val_accuracy: 0.9670
# Epoch 14/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9636 - val_loss: 0.1559 - val_accuracy: 0.9667
# Epoch 15/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1642 - accuracy: 0.9638 - val_loss: 0.1442 - val_accuracy: 0.9682
# Epoch 16/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9676 - val_loss: 0.1390 - val_accuracy: 0.9695
# Epoch 17/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1458 - accuracy: 0.9698 - val_loss: 0.1311 - val_accuracy: 0.9711
# Epoch 18/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 0.9678 - val_loss: 0.1283 - val_accuracy: 0.9712
# Epoch 19/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9712 - val_loss: 0.1195 - val_accuracy: 0.9727
# Epoch 20/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9715 - val_loss: 0.1242 - val_accuracy: 0.9703
# Epoch 21/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9703 - val_loss: 0.1221 - val_accuracy: 0.9714
# Epoch 22/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.9733 - val_loss: 0.1200 - val_accuracy: 0.9705
# Epoch 23/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1166 - accuracy: 0.9733 - val_loss: 0.1059 - val_accuracy: 0.9748
# Epoch 24/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9733 - val_loss: 0.1078 - val_accuracy: 0.9740
# Epoch 25/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.9761 - val_loss: 0.1053 - val_accuracy: 0.9743
# Epoch 26/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1128 - accuracy: 0.9747 - val_loss: 0.1019 - val_accuracy: 0.9758
# Epoch 27/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1110 - accuracy: 0.9743 - val_loss: 0.1034 - val_accuracy: 0.9738
# Epoch 28/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 0.9758 - val_loss: 0.0943 - val_accuracy: 0.9783
# Epoch 29/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9769 - val_loss: 0.0902 - val_accuracy: 0.9787
# Epoch 30/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9775 - val_loss: 0.1045 - val_accuracy: 0.9735
# Epoch 31/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9771 - val_loss: 0.0940 - val_accuracy: 0.9754
# Epoch 32/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9781 - val_loss: 0.0887 - val_accuracy: 0.9784
# Epoch 33/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9780 - val_loss: 0.1146 - val_accuracy: 0.9663
# Epoch 34/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9774 - val_loss: 0.0841 - val_accuracy: 0.9797
# Epoch 35/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0895 - accuracy: 0.9794 - val_loss: 0.0909 - val_accuracy: 0.9760
# Epoch 36/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9773 - val_loss: 0.0962 - val_accuracy: 0.9743
# Epoch 37/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 0.9765 - val_loss: 0.0781 - val_accuracy: 0.9809
# Epoch 38/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9806 - val_loss: 0.0773 - val_accuracy: 0.9807
# Epoch 39/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0830 - accuracy: 0.9806 - val_loss: 0.0765 - val_accuracy: 0.9811
# Epoch 40/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9787 - val_loss: 0.0839 - val_accuracy: 0.9784
# Epoch 41/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9789 - val_loss: 0.0771 - val_accuracy: 0.9808
# Epoch 42/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9800 - val_loss: 0.0733 - val_accuracy: 0.9823
# Epoch 43/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9800 - val_loss: 0.0718 - val_accuracy: 0.9834
# Epoch 44/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9801 - val_loss: 0.0779 - val_accuracy: 0.9797
# Epoch 45/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9799 - val_loss: 0.0720 - val_accuracy: 0.9833
# Epoch 46/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 0.9816 - val_loss: 0.0762 - val_accuracy: 0.9821
# Epoch 47/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0823 - accuracy: 0.9800 - val_loss: 0.0754 - val_accuracy: 0.9808
# Epoch 48/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9816 - val_loss: 0.0711 - val_accuracy: 0.9813
# Epoch 49/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9821 - val_loss: 0.0811 - val_accuracy: 0.9785
# Epoch 50/50
# 192/192 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9820 - val_loss: 0.0779 - val_accuracy: 0.9789
# Time for training:     22.868

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 1s 855us/step - loss: 0.0833 - accuracy: 0.9797
# Test results - Loss: 0.08332124352455139 - Accuracy: 0.9796666502952576%
# Time for testing:      0.541
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-01-23-48-40_mlp_X_56_10_Y_32x32_sauvola_75000_loss_0.0833_acc_0.9797

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
