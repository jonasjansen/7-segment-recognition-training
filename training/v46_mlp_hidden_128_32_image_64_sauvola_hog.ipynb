# %% [markdown]
# Training v46
# --
# ------------------------------------------------------
# 64x64 - Sauvola HOG - 75.000 Images
#
# NN - Input > Hidden 128 > Hidden 32 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 64
COLOR_TYPE = 'sauvola_hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER_1 = 128
HIDDEN_LAYER_2 = 32

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER_1, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(HIDDEN_LAYER_2, activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 3s 12ms/step - loss: 0.7007 - accuracy: 0.8203 - val_loss: 0.0377 - val_accuracy: 0.9954
# Epoch 2/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0328 - accuracy: 0.9961 - val_loss: 0.0210 - val_accuracy: 0.9976
# Epoch 3/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0232 - accuracy: 0.9971 - val_loss: 0.0193 - val_accuracy: 0.9976
# Epoch 4/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0151 - accuracy: 0.9980 - val_loss: 0.0205 - val_accuracy: 0.9958
# Epoch 5/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 0.0198 - val_accuracy: 0.9969
# Epoch 6/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0102 - accuracy: 0.9982 - val_loss: 0.0169 - val_accuracy: 0.9973
# Epoch 7/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.0189 - val_accuracy: 0.9969
# Epoch 8/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0080 - accuracy: 0.9983 - val_loss: 0.0176 - val_accuracy: 0.9973
# Epoch 9/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.0162 - val_accuracy: 0.9974
# Epoch 10/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.0204 - val_accuracy: 0.9965
# Epoch 11/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0208 - val_accuracy: 0.9960
# Epoch 12/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0200 - val_accuracy: 0.9967
# Epoch 13/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0176 - val_accuracy: 0.9972
# Epoch 14/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0197 - val_accuracy: 0.9970
# Epoch 15/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0186 - val_accuracy: 0.9974
# Epoch 16/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0187 - val_accuracy: 0.9973
# Epoch 17/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0234 - val_accuracy: 0.9953
# Epoch 18/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 0.0218 - val_accuracy: 0.9964
# Epoch 19/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0215 - val_accuracy: 0.9973
# Epoch 20/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0242 - val_accuracy: 0.9958
# Epoch 21/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0225 - val_accuracy: 0.9967
# Epoch 22/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0212 - val_accuracy: 0.9969
# Epoch 23/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0291 - val_accuracy: 0.9952
# Epoch 24/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.0279 - val_accuracy: 0.9956
# Epoch 25/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0231 - val_accuracy: 0.9968
# Epoch 26/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0229 - val_accuracy: 0.9972
# Epoch 27/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 0.0247 - val_accuracy: 0.9967
# Epoch 28/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0236 - val_accuracy: 0.9969
# Epoch 29/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0226 - val_accuracy: 0.9969
# Epoch 30/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0247 - val_accuracy: 0.9973
# Epoch 31/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0230 - val_accuracy: 0.9977
# Epoch 32/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0282 - val_accuracy: 0.9962
# Epoch 33/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0240 - val_accuracy: 0.9966
# Epoch 34/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0260 - val_accuracy: 0.9967
# Epoch 35/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0276 - val_accuracy: 0.9965
# Epoch 36/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0228 - val_accuracy: 0.9970
# Epoch 37/50
# 192/192 [==============================] - 1s 7ms/step - loss: 6.6602e-04 - accuracy: 0.9998 - val_loss: 0.0234 - val_accuracy: 0.9972
# Epoch 38/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0283 - val_accuracy: 0.9960
# Epoch 39/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0529 - val_accuracy: 0.9909
# Epoch 40/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0317 - val_accuracy: 0.9963
# Epoch 41/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0265 - val_accuracy: 0.9963
# Epoch 42/50
# 192/192 [==============================] - 1s 7ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0248 - val_accuracy: 0.9975
# Epoch 43/50
# 192/192 [==============================] - 1s 7ms/step - loss: 3.1971e-04 - accuracy: 0.9999 - val_loss: 0.0244 - val_accuracy: 0.9970
# Epoch 44/50
# 192/192 [==============================] - 1s 7ms/step - loss: 1.0344e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 0.9974
# Epoch 45/50
# 192/192 [==============================] - 1s 7ms/step - loss: 6.4135e-04 - accuracy: 0.9999 - val_loss: 0.0241 - val_accuracy: 0.9974
# Epoch 46/50
# 192/192 [==============================] - 1s 7ms/step - loss: 9.5630e-04 - accuracy: 0.9999 - val_loss: 0.0244 - val_accuracy: 0.9973
# Epoch 47/50
# 192/192 [==============================] - 1s 7ms/step - loss: 4.1514e-04 - accuracy: 0.9999 - val_loss: 0.0254 - val_accuracy: 0.9975
# Epoch 48/50
# 192/192 [==============================] - 1s 7ms/step - loss: 5.5928e-04 - accuracy: 0.9999 - val_loss: 0.0268 - val_accuracy: 0.9973
# Epoch 49/50
# 192/192 [==============================] - 1s 7ms/step - loss: 2.0430e-04 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9974
# Epoch 50/50
# 192/192 [==============================] - 1s 7ms/step - loss: 1.0871e-04 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9976
# Time for training:     69.626

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 1s 1ms/step - loss: 0.0286 - accuracy: 0.9973
# Test results - Loss: 0.028617070987820625 - Accuracy: 0.9972666501998901%
# Time for testing:      0.675
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER_1) + '_'\
             + str(HIDDEN_LAYER_2) +'_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-02-10-03-40_mlp_X_128_32_10_Y_64x64_sauvola_hog_75000_loss_0.0286_acc_0.9973

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
