# %% [markdown]
# Training v33
# --
# ------------------------------------------------------
# 32x32 - Sauvola HOG - 75.000 Images
#
# NN - Input > Hidden 128 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 32
COLOR_TYPE = 'sauvola_hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 128

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 2s 7ms/step - loss: 0.8553 - accuracy: 0.7920 - val_loss: 0.1370 - val_accuracy: 0.9795
# Epoch 2/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.1156 - accuracy: 0.9847 - val_loss: 0.0722 - val_accuracy: 0.9893
# Epoch 3/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0522 - val_accuracy: 0.9909
# Epoch 4/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0473 - accuracy: 0.9932 - val_loss: 0.0425 - val_accuracy: 0.9916
# Epoch 5/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0386 - accuracy: 0.9940 - val_loss: 0.0375 - val_accuracy: 0.9926
# Epoch 6/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0317 - accuracy: 0.9953 - val_loss: 0.0324 - val_accuracy: 0.9937
# Epoch 7/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0276 - accuracy: 0.9957 - val_loss: 0.0301 - val_accuracy: 0.9939
# Epoch 8/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0262 - accuracy: 0.9961 - val_loss: 0.0298 - val_accuracy: 0.9948
# Epoch 9/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0226 - accuracy: 0.9965 - val_loss: 0.0279 - val_accuracy: 0.9952
# Epoch 10/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0229 - accuracy: 0.9967 - val_loss: 0.0238 - val_accuracy: 0.9959
# Epoch 11/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0179 - accuracy: 0.9975 - val_loss: 0.0275 - val_accuracy: 0.9940
# Epoch 12/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0205 - accuracy: 0.9960 - val_loss: 0.0249 - val_accuracy: 0.9952
# Epoch 13/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 0.0259 - val_accuracy: 0.9952
# Epoch 14/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0153 - accuracy: 0.9974 - val_loss: 0.0217 - val_accuracy: 0.9962
# Epoch 15/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0143 - accuracy: 0.9975 - val_loss: 0.0222 - val_accuracy: 0.9960
# Epoch 16/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0130 - accuracy: 0.9977 - val_loss: 0.0215 - val_accuracy: 0.9959
# Epoch 17/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0130 - accuracy: 0.9978 - val_loss: 0.0227 - val_accuracy: 0.9956
# Epoch 18/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0123 - accuracy: 0.9976 - val_loss: 0.0207 - val_accuracy: 0.9961
# Epoch 19/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.0233 - val_accuracy: 0.9957
# Epoch 20/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 0.0240 - val_accuracy: 0.9951
# Epoch 21/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9981 - val_loss: 0.0218 - val_accuracy: 0.9958
# Epoch 22/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9980 - val_loss: 0.0216 - val_accuracy: 0.9961
# Epoch 23/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9980 - val_loss: 0.0223 - val_accuracy: 0.9959
# Epoch 24/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.9975 - val_loss: 0.0210 - val_accuracy: 0.9961
# Epoch 25/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 0.9985 - val_loss: 0.0318 - val_accuracy: 0.9928
# Epoch 26/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9981 - val_loss: 0.0217 - val_accuracy: 0.9961
# Epoch 27/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.0223 - val_accuracy: 0.9963
# Epoch 28/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.0270 - val_accuracy: 0.9952
# Epoch 29/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0253 - val_accuracy: 0.9952
# Epoch 30/50
# 192/192 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.0374 - val_accuracy: 0.9916
# Epoch 31/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0233 - val_accuracy: 0.9960
# Epoch 32/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0241 - val_accuracy: 0.9958
# Epoch 33/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0235 - val_accuracy: 0.9957
# Epoch 34/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.9988 - val_loss: 0.0261 - val_accuracy: 0.9953
# Epoch 35/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0243 - val_accuracy: 0.9959
# Epoch 36/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0263 - val_accuracy: 0.9958
# Epoch 37/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0232 - val_accuracy: 0.9958
# Epoch 38/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0267 - val_accuracy: 0.9955
# Epoch 39/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0258 - val_accuracy: 0.9956
# Epoch 40/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0235 - val_accuracy: 0.9960
# Epoch 41/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0257 - val_accuracy: 0.9958
# Epoch 42/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0255 - val_accuracy: 0.9959
# Epoch 43/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.0233 - val_accuracy: 0.9962
# Epoch 44/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0255 - val_accuracy: 0.9952
# Epoch 45/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0258 - val_accuracy: 0.9959
# Epoch 46/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 0.0282 - val_accuracy: 0.9955
# Epoch 47/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0256 - val_accuracy: 0.9961
# Epoch 48/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0345 - val_accuracy: 0.9925
# Epoch 49/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0276 - val_accuracy: 0.9952
# Epoch 50/50
# 192/192 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0242 - val_accuracy: 0.9962
# Time for training:     27.216

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 0s 752us/step - loss: 0.0278 - accuracy: 0.9961
# Test results - Loss: 0.027768993750214577 - Accuracy: 0.9961333274841309%
# Time for testing:      0.463
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-02-00-26-07_mlp_X_128_10_Y_32x32_sauvola_hog_75000_loss_0.0278_acc_0.9961

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
