# %% [markdown]
# Training v34
# --
# ------------------------------------------------------
# 128x128 - Sauvola HOG - 75.000 Images
#
# NN - Input > Hidden 128 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 128
COLOR_TYPE = 'sauvola_hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 128

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 8s 41ms/step - loss: 0.4042 - accuracy: 0.8959 - val_loss: 0.0264 - val_accuracy: 0.9972
# Epoch 2/50
# 192/192 [==============================] - 6s 32ms/step - loss: 0.0230 - accuracy: 0.9973 - val_loss: 0.0191 - val_accuracy: 0.9972
# Epoch 3/50
#  - ETA: 1s - loss: 0.0136 - accuracy: 0.9981
# Epoch 4/50
# 192/192 [==============================] - 6s 33ms/step - loss: 0.0100 - accuracy: 0.9983 - val_loss: 0.0171 - val_accuracy: 0.9974
# Epoch 5/50
# 192/192 [==============================] - 6s 33ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.0154 - val_accuracy: 0.9977
# Epoch 6/50
# 192/192 [==============================] - 6s 34ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0163 - val_accuracy: 0.9971
# Epoch 7/50
# 192/192 [==============================] - 6s 33ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0166 - val_accuracy: 0.9973
# Epoch 8/50
#  - ETA: 0s - loss: 0.0037 - accuracy: 0.9992
# Epoch 9/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0038 - accuracy: 0.9992 - val_loss: 0.0166 - val_accuracy: 0.9976
# Epoch 10/50
# 192/192 [==============================] - 7s 36ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.0197 - val_accuracy: 0.9965
# Epoch 11/50
# 192/192 [==============================] - 6s 33ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0203 - val_accuracy: 0.9967
# Epoch 12/50
# 192/192 [==============================] - 6s 33ms/step - loss: 0.0039 - accuracy: 0.9993 - val_loss: 0.0173 - val_accuracy: 0.9975
# Epoch 13/50
# 192/192 [==============================] - 6s 34ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0240 - val_accuracy: 0.9950
# Epoch 14/50
#  - ETA: 2s - loss: 0.0042 - accuracy: 0.9987
# Epoch 15/50
# 192/192 [==============================] - 6s 34ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0210 - val_accuracy: 0.9970
# Epoch 16/50
# 192/192 [==============================] - 6s 34ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0261 - val_accuracy: 0.9953
# Epoch 17/50
#  - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 18/50
# 192/192 [==============================] - 7s 36ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0215 - val_accuracy: 0.9973
# Epoch 19/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0205 - val_accuracy: 0.9974
# Epoch 20/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0278 - val_accuracy: 0.9959
# Epoch 21/50
#  - ETA: 3s - loss: 0.0056 - accuracy: 0.9980
# Epoch 22/50
#  - ETA: 0s - loss: 7.6102e-04 - accuracy: 0.9999
# Epoch 23/50
# 192/192 [==============================] - 7s 35ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0224 - val_accuracy: 0.9971
# Epoch 24/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0293 - val_accuracy: 0.9961
# Epoch 25/50
# 192/192 [==============================] - 7s 35ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0274 - val_accuracy: 0.9970
# Epoch 26/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0261 - val_accuracy: 0.9969
# Epoch 27/50
# 192/192 [==============================] - 7s 34ms/step - loss: 5.6176e-04 - accuracy: 0.9999 - val_loss: 0.0278 - val_accuracy: 0.9970
# Epoch 28/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0312 - val_accuracy: 0.9961
# Epoch 29/50
# 192/192 [==============================] - 7s 34ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0319 - val_accuracy: 0.9962
# Epoch 30/50
#  - ETA: 3s - loss: 0.0029 - accuracy: 0.9991
# Epoch 31/50
# 192/192 [==============================] - 7s 35ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0297 - val_accuracy: 0.9967
# Epoch 32/50
# 192/192 [==============================] - 7s 35ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0288 - val_accuracy: 0.9970
# Epoch 33/50
# 192/192 [==============================] - 7s 35ms/step - loss: 6.8926e-04 - accuracy: 0.9999 - val_loss: 0.0273 - val_accuracy: 0.9972
# Epoch 34/50
# 192/192 [==============================] - 6s 34ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0258 - val_accuracy: 0.9975
# Epoch 35/50
# 192/192 [==============================] - 7s 34ms/step - loss: 7.2015e-05 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9977
# Epoch 36/50
#  - ETA: 3s - loss: 9.3163e-06 - accuracy: 1.0000
# Epoch 37/50
# 192/192 [==============================] - 6s 34ms/step - loss: 9.5045e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9977
# Epoch 38/50
#  - ETA: 0s - loss: 6.9216e-06 - accuracy: 1.0000
# Epoch 39/50
# 192/192 [==============================] - 6s 34ms/step - loss: 6.0260e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9977
# Epoch 40/50
# 192/192 [==============================] - 6s 34ms/step - loss: 6.2447e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9978
# Epoch 41/50
# 192/192 [==============================] - 6s 33ms/step - loss: 5.8953e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9978
# Epoch 42/50
# 192/192 [==============================] - 6s 33ms/step - loss: 4.8263e-06 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9978
# Epoch 43/50
# 192/192 [==============================] - 6s 33ms/step - loss: 5.2910e-06 - accuracy: 1.0000 - val_loss: 0.0257 - val_accuracy: 0.9978
# Epoch 44/50
#  - ETA: 0s - loss: 3.8378e-06 - accuracy: 1.0000
# Epoch 45/50
# 192/192 [==============================] - 6s 33ms/step - loss: 3.7922e-06 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9978
# Epoch 46/50
# 192/192 [==============================] - 6s 34ms/step - loss: 4.5796e-06 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 0.9978
# Epoch 47/50
#  - ETA: 5s - loss: 3.2490e-06 - accuracy: 1.0000
# Epoch 48/50
# 192/192 [==============================] - 6s 34ms/step - loss: 3.9743e-06 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9978
# Epoch 49/50
# 192/192 [==============================] - 6s 33ms/step - loss: 3.1491e-06 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9978
# Epoch 50/50
# 192/192 [==============================] - 6s 33ms/step - loss: 2.9267e-06 - accuracy: 1.0000 - val_loss: 0.0260 - val_accuracy: 0.9978
# Time for training:    327.741

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0289 - accuracy: 0.9977
# Test results - Loss: 0.02890762686729431 - Accuracy: 0.9976666569709778%
# Time for testing:      1.705
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-02-00-51-35_mlp_X_128_10_Y_128x128_sauvola_hog_75000_loss_0.0289_acc_0.9977

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
