# %% [markdown]
# Training v38
# --
# ------------------------------------------------------
# 64x64 - HOG - 75.000 Images
#
# NN - Input > Hidden 56 > Output
#
# 50 Epochs
#
# ------------------------------------------------------

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import time
from time import gmtime, strftime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from training import dataset as seven_segment_ds

# %% [markdown]
# Define constants

# %%
NUM_CLASSES = 10
IMAGE_SIZE = 64
COLOR_TYPE = 'hog'
BATCH_SIZE = 75000
EPOCHS = 50
HIDDEN_LAYER = 56

# %% [markdown]
# Load data

# %%
(X_train, Y_train), (X_test, Y_test) = seven_segment_ds.load_data(
    image_size=IMAGE_SIZE,
    color_type=COLOR_TYPE,
    batch_size=BATCH_SIZE
)

# %% [markdown]
# Plot Images

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)

    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(Y_train[i])
plt.show()

# %% [markdown]
# Prepare data

# %%
# Reshape the data - MLPs do not understand such things as '2D'.
feature_vector_length = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], feature_vector_length)
X_test = X_test.reshape(X_test.shape[0], feature_vector_length)

# Convert into greyscale
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Convert target classes to categorical ones
Y_train = to_categorical(Y_train, NUM_CLASSES)
Y_test = to_categorical(Y_test, NUM_CLASSES)

# %% [markdown]
# Define Model

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER, input_shape= (feature_vector_length,), activation='relu'))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %% [markdown]
# Train Model

# %%
time_start = time.perf_counter()
model.fit(
    X_train,
    Y_train,
    epochs=EPOCHS,
    batch_size=250,
    verbose=1,
    validation_split=0.2
)
time_stop = time.perf_counter()

print('Time for training:', "{:10.3f}".format(time_stop - time_start))
# Out:
# Epoch 1/50
# 192/192 [==============================] - 2s 11ms/step - loss: 0.9938 - accuracy: 0.7604 - val_loss: 0.1455 - val_accuracy: 0.9871
# Epoch 2/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.1158 - accuracy: 0.9908 - val_loss: 0.0693 - val_accuracy: 0.9917
# Epoch 3/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0613 - accuracy: 0.9936 - val_loss: 0.0473 - val_accuracy: 0.9937
# Epoch 4/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0407 - accuracy: 0.9960 - val_loss: 0.0397 - val_accuracy: 0.9938
# Epoch 5/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0304 - accuracy: 0.9966 - val_loss: 0.0335 - val_accuracy: 0.9947
# Epoch 6/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0253 - accuracy: 0.9969 - val_loss: 0.0291 - val_accuracy: 0.9948
# Epoch 7/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0223 - accuracy: 0.9974 - val_loss: 0.0288 - val_accuracy: 0.9944
# Epoch 8/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0173 - accuracy: 0.9981 - val_loss: 0.0275 - val_accuracy: 0.9951
# Epoch 9/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0150 - accuracy: 0.9980 - val_loss: 0.0288 - val_accuracy: 0.9945
# Epoch 10/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0145 - accuracy: 0.9982 - val_loss: 0.0245 - val_accuracy: 0.9953
# Epoch 11/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0124 - accuracy: 0.9980 - val_loss: 0.0239 - val_accuracy: 0.9957
# Epoch 12/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0094 - accuracy: 0.9988 - val_loss: 0.0229 - val_accuracy: 0.9960
# Epoch 13/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0092 - accuracy: 0.9988 - val_loss: 0.0236 - val_accuracy: 0.9955
# Epoch 14/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0078 - accuracy: 0.9990 - val_loss: 0.0244 - val_accuracy: 0.9956
# Epoch 15/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.0247 - val_accuracy: 0.9949
# Epoch 16/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0048 - accuracy: 0.9995 - val_loss: 0.0244 - val_accuracy: 0.9958
# Epoch 17/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0250 - val_accuracy: 0.9951
# Epoch 18/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.0242 - val_accuracy: 0.9959
# Epoch 19/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 0.0261 - val_accuracy: 0.9955
# Epoch 20/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0243 - val_accuracy: 0.9955
# Epoch 21/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0233 - val_accuracy: 0.9958
# Epoch 22/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0236 - val_accuracy: 0.9958
# Epoch 23/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0254 - val_accuracy: 0.9958
# Epoch 24/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0274 - val_accuracy: 0.9948
# Epoch 25/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0242 - val_accuracy: 0.9960
# Epoch 26/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0244 - val_accuracy: 0.9961
# Epoch 27/50
# 192/192 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0250 - val_accuracy: 0.9961
# Epoch 28/50
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2771e-04 - accuracy: 1.0000 - val_loss: 0.0252 - val_accuracy: 0.9959
# Epoch 29/50
# 192/192 [==============================] - 1s 5ms/step - loss: 7.6893e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9955
# Epoch 30/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0291 - val_accuracy: 0.9951
# Epoch 31/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0458 - val_accuracy: 0.9908
# Epoch 32/50
# 192/192 [==============================] - 1s 5ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0280 - val_accuracy: 0.9959
# Epoch 33/50
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3196e-04 - accuracy: 0.9999 - val_loss: 0.0271 - val_accuracy: 0.9959
# Epoch 34/50
# 192/192 [==============================] - 1s 6ms/step - loss: 4.8128e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9960
# Epoch 35/50
# 192/192 [==============================] - 1s 5ms/step - loss: 3.6612e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9962
# Epoch 36/50
# 192/192 [==============================] - 1s 6ms/step - loss: 3.2745e-04 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9962
# Epoch 37/50
# 192/192 [==============================] - 1s 5ms/step - loss: 3.1354e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 0.9963
# Epoch 38/50
# 192/192 [==============================] - 1s 6ms/step - loss: 2.6583e-04 - accuracy: 1.0000 - val_loss: 0.0274 - val_accuracy: 0.9960
# Epoch 39/50
# 192/192 [==============================] - 1s 6ms/step - loss: 2.7190e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9961
# Epoch 40/50
# 192/192 [==============================] - 1s 6ms/step - loss: 2.4232e-04 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9962
# Epoch 41/50
# 192/192 [==============================] - 1s 6ms/step - loss: 2.2489e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 0.9962
# Epoch 42/50
# 192/192 [==============================] - 1s 6ms/step - loss: 2.3411e-04 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9961
# Epoch 43/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.9842e-04 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9962
# Epoch 44/50
# 192/192 [==============================] - 1s 5ms/step - loss: 1.9182e-04 - accuracy: 1.0000 - val_loss: 0.0290 - val_accuracy: 0.9962
# Epoch 45/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.6615e-04 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9961
# Epoch 46/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.6668e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9959
# Epoch 47/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.6137e-04 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9962
# Epoch 48/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.4163e-04 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9962
# Epoch 49/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.2400e-04 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9962
# Epoch 50/50
# 192/192 [==============================] - 1s 6ms/step - loss: 1.0881e-04 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9962
# Time for training:     54.241

# %% [markdown]
# Test Model

# %%
# Test the model after training
time_start = time.perf_counter()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
time_stop = time.perf_counter()

time_diff = time_stop - time_start
print('Time for testing:', "{:10.3f}".format(time_diff))
print('Time per image:  ', "{:10.3f}".format(time_diff / 15000))
# Out:
# 469/469 [==============================] - 1s 940us/step - loss: 0.0307 - accuracy: 0.9960
# Test results - Loss: 0.030742108821868896 - Accuracy: 0.9959999918937683%
# Time for testing:      0.573
# Time per image:        0.000

# %% [markdown]
# Save Model

# %%
model_name = strftime("%Y-%m-%d-%H-%M-%S", gmtime()) + '_mlp_X_' + str(HIDDEN_LAYER) + '_10_Y_' \
             + str(IMAGE_SIZE) + 'x' + str(IMAGE_SIZE) + '_' + str(COLOR_TYPE) + '_' + str(BATCH_SIZE) \
             + '_loss_' + "{:2.4f}".format(test_results[0]) + '_acc_' + "{:2.4f}".format(test_results[1])
model.save_weights('./checkpoints/' + model_name)
model.save('./models/' + model_name + '.h5')

print("Model saved as " + model_name)
# Out:
# Model saved as 2021-03-02-08-04-03_mlp_X_56_10_Y_64x64_hog_75000_loss_0.0307_acc_0.9960

# %% [markdown]
# Models Saved at:
#
# 2021-03-01-22-56-00_mlp_X_56_10_Y_32x32_gray_75000_loss_0.0903_acc_0.9826
